# %% [markdown]
# # Print Permutations

# %% [markdown]
# ## Approach 1 - Using Data Structure

# %% [markdown]
# - Always Carry Data Structure in recursion, and mark the element which is already picked up.

# %% [markdown]
# ![take U forward - L12. Print all Permutations of a StringArray Recursion Approach - 1 [YK78FU5Ffjw - 885x498 - 7m16s].png](data:image/png;base64,...)

# %% [markdown]
# ![take U forward - L12. Print all Permutations of a StringArray Recursion Approach - 1 [YK78FU5Ffjw - 853x480 - 10m47s].png](data:image/png;base64,...)

# %% [markdown]
# ![take U forward - L12. Print all Permutations of a StringArray Recursion Approach - 1 [YK78FU5Ffjw - 1435x807 - 13m40s].png](data:image/png;base64,...)

# %% [markdown]
# ![take U forward - L12. Print all Permutations of a StringArray Recursion Approach - 1 [YK78FU5Ffjw - 1536x864 - 18m20s].png](data:image/png;base64,...)

# %% [markdown]
# ## Approach 2 - Without using Data Structure - Swaping Method

# %% [markdown]
# Intuatuin - Every number should be at every index

# %% [markdown]
# ![take U forward - L13. Print all Permutations of a StringArray Recursion Approach - 2 [f2ic2Rsc9pU - 1536x864 - 10m05s].png](data:image/png;base64,...)

# %% [markdown]
# Pseudo Code, TC , SC :

# %% [markdown]
# ![take U forward - L13. Print all Permutations of a StringArray Recursion Approach - 2 [f2ic2Rsc9pU - 1536x864 - 14m32s].png](data:image/png;base64,...)

# %% [markdown]
# ![NewPermutation.gif](data:image/gif;base64,...)

# %% [markdown]
# ![take U forward - L13. Print all Permutations of a StringArray Recursion Approach - 2 [f2ic2Rsc9pU - 1536x864 - 16m18s].png](data:image/png;base64,...)

# %% [markdown]
# # Next Permutation -
